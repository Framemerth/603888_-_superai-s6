# %%
import pandas as pd

# %%
data = {
    "name": ["Braund, Mr. Owen Harris", "Allen, Mr. William Henry", "Bonnell, Miss. Elizabeth","frame","mojo"],
    "age" : [22, 35, 58,22,1],
    "sex" : ["male", "male", "female","male","female"],
    "score": [80,75,90,85,10]
}
df = pd.DataFrame(data)
df
# Out:
#                        name  age     sex  score
# 0   Braund, Mr. Owen Harris   22    male     80
# 1  Allen, Mr. William Henry   35    male     75
# 2  Bonnell, Miss. Elizabeth   58  female     90
# 3                     frame   22    male     85
# 4                      mojo    1  female     10

# %% [markdown]
# # **ดูข้อมูล**

# %%
df.head() #ดูแค่หัว โดยปกติ5 แถวแรก
# Out:
#                        name  age     sex  score
# 0   Braund, Mr. Owen Harris   22    male     80
# 1  Allen, Mr. William Henry   35    male     75
# 2  Bonnell, Miss. Elizabeth   58  female     90
# 3                     frame   22    male     85
# 4                      mojo    1  female     10

# %%
df.columns #ดูว่าคอลัมล์มีอะไรบ้าง
# Out:
# Index(['name', 'age', 'sex', 'score'], dtype='object')

# %%
df.shape #ขนาดเท่าไร อันนี้คือ 5 แถว 4 คอลัมล์
# Out:
# (5, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   sex     5 non-null      object
#  3   score   5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe() #ต่าสิถิตต่างๆเช่น min max ระดับ 25% 50% 75%
# Out:
#              age      score
# count   5.000000   5.000000
# mean   27.600000  68.000000
# std    20.911719  32.901368
# min     1.000000  10.000000
# 25%    22.000000  75.000000
# 50%    22.000000  80.000000
# 75%    35.000000  85.000000
# max    58.000000  90.000000

# %% [markdown]
# # **วิเคราะห์ข้อมูล**

# %%
df["score"].mean() #ค่าเฉลี่ยของ score
# Out:
# np.float64(68.0)

# %%
df["score"].max() #ค่าสูงที่สุด
# Out:
# 90

# %%
df["score"].min()#ค่าต่ำที่สุด
# Out:
# 10

# %% [markdown]
# # filter **data**

# %%
df[df["score"]>80] # ให้กรอง score ว่ามีใครบ้างที่มีค่ามากกว่า 80 คะแนน
# Out:
#                        name  age     sex  score
# 2  Bonnell, Miss. Elizabeth   58  female     90
# 3                     frame   22    male     85

# %%
df[df["score"]<50] # ให้กรอง score ว่ามีใครบ้างที่มีค่าน้อยกว่า 50 คะแนน
# Out:
#    name  age     sex  score
# 4  mojo    1  female     10

# %%
df["score"].value_counts()
# Out:
# score
# 80    1
# 75    1
# 90    1
# 85    1
# 10    1
# Name: count, dtype: int64

# %%
df.sort_values("score")
# Out:
#                        name  age     sex  score
# 4                      mojo    1  female     10
# 1  Allen, Mr. William Henry   35    male     75
# 0   Braund, Mr. Owen Harris   22    male     80
# 3                     frame   22    male     85
# 2  Bonnell, Miss. Elizabeth   58  female     90

# %%
df.sort_values("score", ascending=False)
# Out:
#                        name  age     sex  score
# 2  Bonnell, Miss. Elizabeth   58  female     90
# 3                     frame   22    male     85
# 0   Braund, Mr. Owen Harris   22    male     80
# 1  Allen, Mr. William Henry   35    male     75
# 4                      mojo    1  female     10

# %%
df["score"].median()
# Out:
# 80.0

# %%
df["score"].plot(kind="bar")
# Out:
# <Axes: >
